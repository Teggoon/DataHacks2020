# %%
import numpy as np
import pandas as pd 
from datascience import *

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')


housing = pd.read_csv('SD1970_housing.csv', thousands = ',')
population = pd.read_csv('SD1970_population.csv',thousands = ',')

population
# Out:
#        Census Tract Name  Block Group  Place Name  Total persons  \
# 0     Census Tract 1                1   San Diego            901
# 1     Census Tract 1                2   San Diego            683
# 2     Census Tract 1                3   San Diego            532
# 3     Census Tract 1                4   San Diego            421
# 4     Census Tract 1                5   San Diego            489
# 5     Census Tract 1                6   San Diego            498
# 6     Census Tract 1                9   San Diego              6
# 7     Census Tract 2                1   San Diego           1082
# 8     Census Tract 2                2   San Diego           2151
# 9     Census Tract 2                3   San Diego           1348
# 10    Census Tract 2                4   San Diego            960
# 11    Census Tract 2                5   San Diego            434
# 12    Census Tract 2                8   San Diego              2
# ...

# %%
population = population.replace('...',np.NaN)
columns = ['Male persons age under 5 years','Male persons age 5 years','Male persons age 6 years','Male persons age 7-9 years','Male persons age 10-13 years','Male persons age 14 years','Male persons age 15 years','Male persons age 16 years','Male persons age 17 years','Male persons age 18 years','Male persons age 19 years','Male persons age 20 years','Male persons age 21 years','Male persons age 22-24 years']
for i in columns:
    population[i] = pd.to_numeric(population[i])
population['Male persons age 5-24'] = population['Male persons age 5 years']+population['Male persons age 6 years']+population['Male persons age 7-9 years']+population['Male persons age 10-13 years']+population['Male persons age 14 years']+population['Male persons age 15 years']+population['Male persons age 16 years']+population['Male persons age 17 years']+population['Male persons age 18 years']+population['Male persons age 19 years']+population['Male persons age 20 years']+population['Male persons age 21 years']+population['Male persons age 22-24 years']
population = population.drop(columns=['Male persons age 5 years','Male persons age 6 years','Male persons age 7-9 years','Male persons age 10-13 years','Male persons age 14 years','Male persons age 15 years','Male persons age 16 years','Male persons age 17 years','Male persons age 18 years','Male persons age 19 years','Male persons age 20 years','Male persons age 21 years','Male persons age 22-24 years'])
population
# Out:
#        Census Tract Name  Block Group  Place Name  Total persons  \
# 0     Census Tract 1                1   San Diego            901
# 1     Census Tract 1                2   San Diego            683
# 2     Census Tract 1                3   San Diego            532
# 3     Census Tract 1                4   San Diego            421
# 4     Census Tract 1                5   San Diego            489
# 5     Census Tract 1                6   San Diego            498
# 6     Census Tract 1                9   San Diego              6
# 7     Census Tract 2                1   San Diego           1082
# 8     Census Tract 2                2   San Diego           2151
# 9     Census Tract 2                3   San Diego           1348
# 10    Census Tract 2                4   San Diego            960
# 11    Census Tract 2                5   San Diego            434
# 12    Census Tract 2                8   San Diego              2
# ...
